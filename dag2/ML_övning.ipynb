# %% [markdown]
# <a href="https://colab.research.google.com/github/Vastra-Gotalandsregionen/AI_utbildning/blob/main/dag2/ML_%C3%B6vning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **Maskininlärning med Python**
# ###**Mål: Bygg en klassificeringmodell för att predicera bröstcancer**
#
# ### **Kod & data:**
# - URL till original-notebooken: **tinyurl.com/2v2u9y4p**
#   - Ladda upp och kör i ert eget google colab-konto
# - Vi kommer ladda in ett öppet dataset med data från bröstcancerpatienter
#   - Datasetet är redan städat, transformerat och bearbetat, så vi kan använda det som det är
#   - <font color="red">**OBS! Ladda aldrig upp sekretessbelagd data (t.ex. patientdata) på google colab!**</font>
#
# ### **Bra att veta:**
# - Från och med **Övning 1** så kommer det stå `...` här och var i koden, där ska ni fylla i kod själva
#   - Läs övningsinstruktionerna för att lista ut vad som ska stå där
# - Kör en specifik kod-cell genom att trycka på play-knappen i övre vänstra hörnet av cellen
#   - Kom ihåg att ordningen som du kör cellerna i spelar roll, om det finns kod i cell A som behövs i cell B så behöver du köra A före B
#   - Om kod i cell B skriver över variabler i cell A, så kommer det påverka vad som händer om du kör A igen

# %%
"""
Först importerar vi de paket vi behöver:
- Vi använder pandas för att hantera tabulärdata
- Vi använder sklearn för allting ML-relaterat
- Notera att pandas har aliaset pd, vilket innebär att vi når dess funktioner med prefixet pd.
"""
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split

pd.options.display.max_columns = None  # Ställer in så pandas dataframes inte kollapsar (döljer) kolumner när vi skriver ut en tabell


"""
Sedan laddar vi in data med datasets.load_breast_cancer():
- X innehåller alla variabler som vi vill använda som input vid prediktion
- Y innehåller den variabel som är vår modells "target", d.v.s det modellen predicerar
"""
X, y = datasets.load_breast_cancer(return_X_y=True, as_frame=True)    # Laddar X- och y-data
y = y.apply(lambda x: datasets.load_breast_cancer().target_names[x])  # Lägger till etiketter till y-data


"""
Slutligen så delar vi upp data i träning- och test-data:
- X_train och y_train är data som ska användas vid träning av modellen
- X_test och y_test är data som ska användas vid utvärdering av modellen
"""
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.6, random_state=1234)

# %% [markdown]
# ---
# # Övning 1 - Bekanta er med datasetet
#
# Data är laddad som pandas DataFrames, vilket innebär att data struktureras som tabeller med kolumner och rader
# - pandas (alias pd) har inbyggda funktioner som kan användas för att hantera dataseten
# - Om ni t.ex. skriver `X_train.head()` så ser ni de fem första raderna i X_train-datasetet
#
# **Uppgifter**:
# 1. Skriv `y_train.value_counts()` för att räkna hur många fall som hade utfallet "benign" respektive "malignant"
# 2. Skriv `X_train.head()` eller `X_train.tail()` för att visa de fem första/sista raderna
#   - Vill ni t.ex. visa 10 rader så kan ni skriva `X_train.head(10)`
# 3. Använd `.describe()` på `X_train` för att få en sammanfattning av datasetet
# 4. Använd `.corr()` på `X_train` för att ta fram en korrelationsmatris

# %%
# 1.1. .value_counts()
y_train.value_counts()
# Out:
# benign       213
# malignant    128
# Name: target, dtype: int64

# %%
# 1.2 .head() or .tail()
X_train.head()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 322        12.86         13.32           82.82      504.8          0.11340
# 93         13.45         18.30           86.60      555.1          0.10220
# 324        12.20         15.21           78.01      457.9          0.08673
# 407        12.85         21.37           82.63      514.5          0.07551
# 404        12.34         14.95           78.29      469.1          0.08682
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 322           0.08834         0.03800              0.03400         0.1543
# 93            0.08165         0.03974              0.02780         0.1638
# 324           0.06545         0.01994              0.01692         0.1638
# 407           0.08316         0.06126              0.01867         0.1580
# 404           0.04571         0.02109              0.02054         0.1571
#
#      mean fractal dimension  radius error  texture error  perimeter error  \
# 322                 0.06476        0.2212         1.0420            1.614
# 93                  0.05710        0.2950         1.3730            2.099
# 324                 0.06129        0.2575         0.8073            1.959
# 407                 0.06114        0.4993         1.7980            2.552
# 404                 0.05708        0.3833         0.9078            2.602
#
#      area error  smoothness error  compactness error  concavity error  \
# 322       16.57          0.005910           0.020160          0.01902
# 93        25.22          0.005884           0.014910          0.01872
# 324       19.01          0.005403           0.014180          0.01051
# 407       41.24          0.006011           0.044800          0.05175
# 404       30.15          0.007702           0.008491          0.01307
#
#      concave points error  symmetry error  fractal dimension error  \
# 322              0.010110         0.01202                 0.003107
# 93               0.009366         0.01884                 0.001817
# 324              0.005142         0.01333                 0.002065
# 407              0.013410         0.02669                 0.007731
# 404              0.010300         0.02970                 0.001432
#
#      worst radius  worst texture  worst perimeter  worst area  \
# 322         14.04          21.08            92.80       599.5
# 93          15.10          25.94            97.59       699.4
# 324         13.75          21.38            91.11       583.1
# 407         14.40          27.01            91.63       645.8
# 404         13.18          16.85            84.11       533.1
#
#      worst smoothness  worst compactness  worst concavity  \
# 322           0.15470            0.22310          0.17910
# 93            0.13390            0.17510          0.13810
# 324           0.12560            0.19280          0.11670
# 407           0.09402            0.19360          0.18380
# 404           0.10480            0.06744          0.04921
#
#      worst concave points  worst symmetry  worst fractal dimension
# 322               0.11550          0.2382                  0.08553
# 93                0.07911          0.2678                  0.06603
# 324               0.05556          0.2661                  0.07961
# 407               0.05601          0.2488                  0.08151
# 404               0.04793          0.2298                  0.05974

# %%
# 1.3 .describe()
X_train.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   341.000000    341.000000      341.000000   341.000000
# mean     14.235378     19.364633       92.727478   666.362757
# std       3.610571      4.358095       24.815378   362.403166
# min       6.981000     10.720000       43.790000   143.500000
# 25%      11.850000     15.940000       76.370000   432.200000
# 50%      13.300000     18.900000       86.490000   546.100000
# 75%      16.070000     21.970000      105.800000   800.000000
# max      28.110000     33.810000      188.500000  2499.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       341.000000        341.000000      341.000000            341.00000
# mean          0.096371          0.105316        0.091355              0.04983
# std           0.014282          0.052911        0.079349              0.03920
# min           0.052630          0.019380        0.000000              0.00000
# 25%           0.086050          0.066690        0.029660              0.02068
# 50%           0.094950          0.094860        0.065050              0.03390
# 75%           0.105400          0.131800        0.142500              0.07944
# max           0.142500          0.311400        0.426400              0.19130
#
#        mean symmetry  mean fractal dimension  radius error  texture error  \
# count     341.000000              341.000000    341.000000     341.000000
# mean        0.182095                0.062733      0.405384       1.230771
# std         0.026128                0.007186      0.275317       0.556630
# min         0.106000                0.049960      0.111500       0.360200
# 25%         0.163300                0.057660      0.231500       0.828200
# 50%         0.180100                0.061270      0.315200       1.142000
# 75%         0.196400                0.066120      0.476800       1.475000
# max         0.274300                0.097440      2.873000       3.896000
#
#        perimeter error  area error  smoothness error  compactness error  \
# count       341.000000  341.000000        341.000000         341.000000
# mean          2.896327   40.487528          0.007018           0.025913
# std           2.065895   43.432908          0.002821           0.018012
# min           0.757000    7.228000          0.002866           0.002252
# 25%           1.648000   17.740000          0.005233           0.013080
# 50%           2.287000   23.920000          0.006428           0.020830
# 75%           3.312000   45.420000          0.008074           0.033180
# max          21.980000  525.600000          0.021770           0.135400
#
#        concavity error  concave points error  symmetry error  \
# count       341.000000            341.000000      341.000000
# mean          0.032203              0.011841        0.020386
# std           0.027167              0.005987        0.007916
# min           0.000000              0.000000        0.007882
# 25%           0.015100              0.008000        0.015270
# 50%           0.027030              0.011100        0.018570
# 75%           0.042660              0.014710        0.022920
# max           0.303800              0.040900        0.061460
#
#        fractal dimension error  worst radius  worst texture  worst perimeter  \
# count               341.000000    341.000000     341.000000       341.000000
# mean                  0.003769     16.402710      25.927654       108.402581
# std                   0.002257      4.909726       6.317725        34.253667
# min                   0.000895      7.930000      12.490000        50.410000
# 25%                   0.002248     13.140000      21.080000        85.080000
# 50%                   0.003211     14.840000      25.730000        97.650000
# 75%                   0.004572     19.380000      30.360000       128.800000
# max                   0.017920     33.130000      49.540000       229.300000
#
#         worst area  worst smoothness  worst compactness  worst concavity  \
# count   341.000000        341.000000         341.000000       341.000000
# mean    895.107918          0.133289           0.264462         0.287925
# std     570.480168          0.023967           0.171489         0.224550
# min     185.200000          0.081250           0.034320         0.000000
# 25%     525.100000          0.117800           0.150600         0.116700
# 50%     675.200000          0.131200           0.217000         0.241300
# 75%    1165.000000          0.146700           0.345800         0.400000
# max    3234.000000          0.222600           1.058000         1.252000
#
#        worst concave points  worst symmetry  worst fractal dimension
# count            341.000000      341.000000               341.000000
# mean               0.117601        0.292818                 0.084867
# std                0.067166        0.061439                 0.019981
# min                0.000000        0.156500                 0.055040
# 25%                0.064980        0.255200                 0.071270
# 50%                0.101500        0.284400                 0.080040
# 75%                0.170800        0.320000                 0.092700
# max                0.291000        0.663800                 0.207500

# %%
# 1.4 .corr()
X_train.corr()
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.318065        0.997855   0.988596
# mean texture                0.318065      1.000000        0.328624   0.309854
# mean perimeter              0.997855      0.328624        1.000000   0.987302
# mean area                   0.988596      0.309854        0.987302   1.000000
# mean smoothness             0.137013      0.011727        0.173369   0.143126
# mean compactness            0.472247      0.295442        0.524562   0.465451
# mean concavity              0.662236      0.335239        0.702922   0.670788
# mean concave points         0.817763      0.318563        0.846701   0.820867
# mean symmetry               0.088062      0.104585        0.121518   0.086596
# mean fractal dimension     -0.350565     -0.016666       -0.301072  -0.322561
# radius error                0.691811      0.268643        0.703397   0.739196
# texture error              -0.100366      0.400117       -0.089729  -0.075302
# perimeter error             0.680722      0.280757        0.698920   0.726549
# area error                  0.756758      0.252178        0.764624   0.809935
# smoothness error           -0.290499     -0.048762       -0.272855  -0.229935
# compactness error           0.171220      0.202503        0.216268   0.174490
# concavity error             0.174191      0.158066        0.209722   0.187747
# concave points error        0.381039      0.172315        0.411337   0.375742
# symmetry error             -0.152753     -0.015431       -0.138363  -0.106373
# fractal dimension error    -0.048092      0.102556       -0.007353  -0.027833
# worst radius                0.971249      0.349523        0.972806   0.962478
# worst texture               0.277154      0.914510        0.289576   0.261569
# worst perimeter             0.963783      0.365160        0.970886   0.955074
# worst area                  0.951661      0.337699        0.953243   0.962963
# worst smoothness            0.091022      0.114220        0.125051   0.089021
# worst compactness           0.354292      0.308837        0.399429   0.331628
# worst concavity             0.462018      0.319502        0.501617   0.446245
# worst concave points        0.722969      0.323214        0.752394   0.700941
# worst symmetry              0.105048      0.141075        0.129475   0.083432
# worst fractal dimension    -0.018770      0.173152        0.027128  -0.024583
#
#                          mean smoothness  mean compactness  mean concavity  \
# mean radius                     0.137013          0.472247        0.662236
# mean texture                    0.011727          0.295442        0.335239
# mean perimeter                  0.173369          0.524562        0.702922
# mean area                       0.143126          0.465451        0.670788
# mean smoothness                 1.000000          0.638582        0.519858
# mean compactness                0.638582          1.000000        0.891290
# mean concavity                  0.519858          0.891290        1.000000
# mean concave points             0.536270          0.814191        0.918344
# mean symmetry                   0.539908          0.562870        0.458234
# mean fractal dimension          0.576360          0.561702        0.322501
# radius error                    0.266098          0.465928        0.610891
# texture error                   0.104885          0.067804        0.054373
# perimeter error                 0.255894          0.519884        0.642280
# area error                      0.223573          0.434879        0.613453
# smoothness error                0.344439          0.101043        0.026237
# compactness error               0.292884          0.741208        0.646170
# concavity error                 0.235341          0.599894        0.677787
# concave points error            0.343612          0.626847        0.647635
# symmetry error                  0.148885          0.130660        0.073408
# fractal dimension error         0.305478          0.567721        0.448151
# worst radius                    0.195199          0.524939        0.693672
# worst texture                   0.100626          0.331925        0.347277
# worst perimeter                 0.217891          0.582263        0.735121
# worst area                      0.191312          0.503792        0.685861
# worst smoothness                0.830714          0.607793        0.477916
# worst compactness               0.465262          0.876252        0.760652
# worst concavity                 0.435163          0.827172        0.876049
# worst concave points            0.495812          0.826384        0.871190
# worst symmetry                  0.390188          0.501116        0.393349
# worst fractal dimension         0.482962          0.711206        0.532767
#
#                          mean concave points  mean symmetry  \
# mean radius                         0.817763       0.088062
# mean texture                        0.318563       0.104585
# mean perimeter                      0.846701       0.121518
# mean area                           0.820867       0.086596
# mean smoothness                     0.536270       0.539908
# mean compactness                    0.814191       0.562870
# mean concavity                      0.918344       0.458234
# mean concave points                 1.000000       0.409421
# mean symmetry                       0.409421       1.000000
# mean fractal dimension              0.134010       0.479020
# radius error                        0.695310       0.252116
# texture error                       0.024154       0.128033
# perimeter error                     0.702733       0.258228
# area error                          0.704385       0.170415
# smoothness error                   -0.028300       0.208462
# compactness error                   0.456333       0.406693
# concavity error                     0.421042       0.316997
# concave points error                0.602653       0.369111
# symmetry error                     -0.000449       0.407175
# fractal dimension error             0.269241       0.349772
# worst radius                        0.839263       0.144380
# worst texture                       0.325068       0.138843
# worst perimeter                     0.862298       0.176052
# worst area                          0.828860       0.133080
# worst smoothness                    0.452943       0.457401
# worst compactness                   0.630330       0.455002
# worst concavity                     0.711271       0.417357
# worst concave points                0.901742       0.399411
# worst symmetry                      0.324536       0.675476
# worst fractal dimension             0.349537       0.429053
#
#                          mean fractal dimension  radius error  texture error  \
# mean radius                           -0.350565      0.691811      -0.100366
# mean texture                          -0.016666      0.268643       0.400117
# mean perimeter                        -0.301072      0.703397      -0.089729
# mean area                             -0.322561      0.739196      -0.075302
# mean smoothness                        0.576360      0.266098       0.104885
# mean compactness                       0.561702      0.465928       0.067804
# mean concavity                         0.322501      0.610891       0.054373
# mean concave points                    0.134010      0.695310       0.024154
# mean symmetry                          0.479020      0.252116       0.128033
# mean fractal dimension                 1.000000     -0.053444       0.177765
# radius error                          -0.053444      1.000000       0.185468
# texture error                          0.177765      0.185468       1.000000
# perimeter error                       -0.003385      0.971058       0.211597
# area error                            -0.131564      0.964849       0.093056
# smoothness error                       0.423969      0.134333       0.415030
# compactness error                      0.548635      0.300396       0.233043
# concavity error                        0.434323      0.291475       0.153074
# concave points error                   0.280815      0.516132       0.260162
# symmetry error                         0.322449      0.232274       0.415108
# fractal dimension error                0.720676      0.187822       0.299861
# worst radius                          -0.274989      0.707897      -0.121282
# worst texture                          0.042689      0.164618       0.431317
# worst perimeter                       -0.225738      0.710499      -0.109977
# worst area                            -0.257267      0.733429      -0.100783
# worst smoothness                       0.548285      0.103281      -0.043216
# worst compactness                      0.492138      0.239479      -0.077826
# worst concavity                        0.378034      0.325272      -0.086871
# worst concave points                   0.181234      0.513578      -0.116394
# worst symmetry                         0.378115      0.040590      -0.130530
# worst fractal dimension                0.779172      0.009311      -0.032758
#
#                          perimeter error  area error  smoothness error  \
# mean radius                     0.680722    0.756758         -0.290499
# mean texture                    0.280757    0.252178         -0.048762
# mean perimeter                  0.698920    0.764624         -0.272855
# mean area                       0.726549    0.809935         -0.229935
# mean smoothness                 0.255894    0.223573          0.344439
# mean compactness                0.519884    0.434879          0.101043
# mean concavity                  0.642280    0.613453          0.026237
# mean concave points             0.702733    0.704385         -0.028300
# mean symmetry                   0.258228    0.170415          0.208462
# mean fractal dimension         -0.003385   -0.131564          0.423969
# radius error                    0.971058    0.964849          0.134333
# texture error                   0.211597    0.093056          0.415030
# perimeter error                 1.000000    0.946302          0.118923
# area error                      0.946302    1.000000          0.048353
# smoothness error                0.118923    0.048353          1.000000
# compactness error               0.382278    0.243085          0.237199
# concavity error                 0.349599    0.257614          0.173905
# concave points error            0.572611    0.432536          0.254251
# symmetry error                  0.251758    0.147843          0.451961
# fractal dimension error         0.248811    0.116907          0.379757
# worst radius                    0.683574    0.753396         -0.282331
# worst texture                   0.176169    0.162338         -0.102064
# worst perimeter                 0.707437    0.753290         -0.272679
# worst area                      0.705355    0.784507         -0.230113
# worst smoothness                0.087530    0.087105          0.315407
# worst compactness               0.294809    0.236047         -0.073297
# worst concavity                 0.363730    0.335307         -0.103741
# worst concave points            0.534099    0.529851         -0.144902
# worst symmetry                  0.043647    0.017186         -0.104290
# worst fractal dimension         0.051213   -0.015306          0.095001
#
#                          compactness error  concavity error  \
# mean radius                       0.171220         0.174191
# mean texture                      0.202503         0.158066
# mean perimeter                    0.216268         0.209722
# mean area                         0.174490         0.187747
# mean smoothness                   0.292884         0.235341
# mean compactness                  0.741208         0.599894
# mean concavity                    0.646170         0.677787
# mean concave points               0.456333         0.421042
# mean symmetry                     0.406693         0.316997
# mean fractal dimension            0.548635         0.434323
# radius error                      0.300396         0.291475
# texture error                     0.233043         0.153074
# perimeter error                   0.382278         0.349599
# area error                        0.243085         0.257614
# smoothness error                  0.237199         0.173905
# compactness error                 1.000000         0.815524
# concavity error                   0.815524         1.000000
# concave points error              0.709407         0.723959
# symmetry error                    0.356745         0.252087
# fractal dimension error           0.810714         0.659503
# worst radius                      0.192908         0.189140
# worst texture                     0.189855         0.140892
# worst perimeter                   0.254162         0.234039
# worst area                        0.185785         0.191764
# worst smoothness                  0.255361         0.200251
# worst compactness                 0.719801         0.554694
# worst concavity                   0.660307         0.715754
# worst concave points              0.499144         0.474606
# worst symmetry                    0.322980         0.238351
# worst fractal dimension           0.633300         0.490538
#
#                          concave points error  symmetry error  \
# mean radius                          0.381039       -0.152753
# mean texture                         0.172315       -0.015431
# mean perimeter                       0.411337       -0.138363
# mean area                            0.375742       -0.106373
# mean smoothness                      0.343612        0.148885
# mean compactness                     0.626847        0.130660
# mean concavity                       0.647635        0.073408
# mean concave points                  0.602653       -0.000449
# mean symmetry                        0.369111        0.407175
# mean fractal dimension               0.280815        0.322449
# radius error                         0.516132        0.232274
# texture error                        0.260162        0.415108
# perimeter error                      0.572611        0.251758
# area error                           0.432536        0.147843
# smoothness error                     0.254251        0.451961
# compactness error                    0.709407        0.356745
# concavity error                      0.723959        0.252087
# concave points error                 1.000000        0.232512
# symmetry error                       0.232512        1.000000
# fractal dimension error              0.548342        0.403464
# worst radius                         0.374291       -0.166441
# worst texture                        0.109997       -0.091604
# worst perimeter                      0.412039       -0.150475
# worst area                           0.360941       -0.138579
# worst smoothness                     0.206007       -0.040858
# worst compactness                    0.440085        0.013690
# worst concavity                      0.514871       -0.033417
# worst concave points                 0.606662       -0.114784
# worst symmetry                       0.115823        0.348089
# worst fractal dimension              0.283571        0.068782
#
#                          fractal dimension error  worst radius  worst texture  \
# mean radius                            -0.048092      0.971249       0.277154
# mean texture                            0.102556      0.349523       0.914510
# mean perimeter                         -0.007353      0.972806       0.289576
# mean area                              -0.027833      0.962478       0.261569
# mean smoothness                         0.305478      0.195199       0.100626
# mean compactness                        0.567721      0.524939       0.331925
# mean concavity                          0.448151      0.693672       0.347277
# mean concave points                     0.269241      0.839263       0.325068
# mean symmetry                           0.349772      0.144380       0.138843
# mean fractal dimension                  0.720676     -0.274989       0.042689
# radius error                            0.187822      0.707897       0.164618
# texture error                           0.299861     -0.121282       0.431317
# perimeter error                         0.248811      0.683574       0.176169
# area error                              0.116907      0.753396       0.162338
# smoothness error                        0.379757     -0.282331      -0.102064
# compactness error                       0.810714      0.192908       0.189855
# concavity error                         0.659503      0.189140       0.140892
# concave points error                    0.548342      0.374291       0.109997
# symmetry error                          0.403464     -0.166441      -0.091604
# fractal dimension error                 1.000000     -0.027892       0.073873
# worst radius                           -0.027892      1.000000       0.338892
# worst texture                           0.073873      0.338892       1.000000
# worst perimeter                         0.017197      0.992959       0.354448
# worst area                             -0.018255      0.988449       0.320433
# worst smoothness                        0.240270      0.201908       0.279962
# worst compactness                       0.494213      0.432545       0.405354
# worst concavity                         0.439184      0.530313       0.396684
# worst concave points                    0.264722      0.781529       0.392790
# worst symmetry                          0.191296      0.205630       0.274336
# worst fractal dimension                 0.695351      0.076485       0.284785
#
#                          worst perimeter  worst area  worst smoothness  \
# mean radius                     0.963783    0.951661          0.091022
# mean texture                    0.365160    0.337699          0.114220
# mean perimeter                  0.970886    0.953243          0.125051
# mean area                       0.955074    0.962963          0.089021
# mean smoothness                 0.217891    0.191312          0.830714
# mean compactness                0.582263    0.503792          0.607793
# mean concavity                  0.735121    0.685861          0.477916
# mean concave points             0.862298    0.828860          0.452943
# mean symmetry                   0.176052    0.133080          0.457401
# mean fractal dimension         -0.225738   -0.257267          0.548285
# radius error                    0.710499    0.733429          0.103281
# texture error                  -0.109977   -0.100783         -0.043216
# perimeter error                 0.707437    0.705355          0.087530
# area error                      0.753290    0.784507          0.087105
# smoothness error               -0.272679   -0.230113          0.315407
# compactness error               0.254162    0.185785          0.255361
# concavity error                 0.234039    0.191764          0.200251
# concave points error            0.412039    0.360941          0.206007
# symmetry error                 -0.150475   -0.138579         -0.040858
# fractal dimension error         0.017197   -0.018255          0.240270
# worst radius                    0.992959    0.988449          0.201908
# worst texture                   0.354448    0.320433          0.279962
# worst perimeter                 1.000000    0.980446          0.222972
# worst area                      0.980446    1.000000          0.193457
# worst smoothness                0.222972    0.193457          1.000000
# worst compactness               0.491336    0.399405          0.595179
# worst concavity                 0.577285    0.504171          0.540093
# worst concave points            0.811336    0.750241          0.558045
# worst symmetry                  0.229314    0.173363          0.528173
# worst fractal dimension         0.125139    0.060754          0.625461
#
#                          worst compactness  worst concavity  \
# mean radius                       0.354292         0.462018
# mean texture                      0.308837         0.319502
# mean perimeter                    0.399429         0.501617
# mean area                         0.331628         0.446245
# mean smoothness                   0.465262         0.435163
# mean compactness                  0.876252         0.827172
# mean concavity                    0.760652         0.876049
# mean concave points               0.630330         0.711271
# mean symmetry                     0.455002         0.417357
# mean fractal dimension            0.492138         0.378034
# radius error                      0.239479         0.325272
# texture error                    -0.077826        -0.086871
# perimeter error                   0.294809         0.363730
# area error                        0.236047         0.335307
# smoothness error                 -0.073297        -0.103741
# compactness error                 0.719801         0.660307
# concavity error                   0.554694         0.715754
# concave points error              0.440085         0.514871
# symmetry error                    0.013690        -0.033417
# fractal dimension error           0.494213         0.439184
# worst radius                      0.432545         0.530313
# worst texture                     0.405354         0.396684
# worst perimeter                   0.491336         0.577285
# worst area                        0.399405         0.504171
# worst smoothness                  0.595179         0.540093
# worst compactness                 1.000000         0.898911
# worst concavity                   0.898911         1.000000
# worst concave points              0.789308         0.840267
# worst symmetry                    0.621446         0.545850
# worst fractal dimension           0.831392         0.718941
#
#                          worst concave points  worst symmetry  \
# mean radius                          0.722969        0.105048
# mean texture                         0.323214        0.141075
# mean perimeter                       0.752394        0.129475
# mean area                            0.700941        0.083432
# mean smoothness                      0.495812        0.390188
# mean compactness                     0.826384        0.501116
# mean concavity                       0.871190        0.393349
# mean concave points                  0.901742        0.324536
# mean symmetry                        0.399411        0.675476
# mean fractal dimension               0.181234        0.378115
# radius error                         0.513578        0.040590
# texture error                       -0.116394       -0.130530
# perimeter error                      0.534099        0.043647
# area error                           0.529851        0.017186
# smoothness error                    -0.144902       -0.104290
# compactness error                    0.499144        0.322980
# concavity error                      0.474606        0.238351
# concave points error                 0.606662        0.115823
# symmetry error                      -0.114784        0.348089
# fractal dimension error              0.264722        0.191296
# worst radius                         0.781529        0.205630
# worst texture                        0.392790        0.274336
# worst perimeter                      0.811336        0.229314
# worst area                           0.750241        0.173363
# worst smoothness                     0.558045        0.528173
# worst compactness                    0.789308        0.621446
# worst concavity                      0.840267        0.545850
# worst concave points                 1.000000        0.483212
# worst symmetry                       0.483212        1.000000
# worst fractal dimension              0.514009        0.563186
#
#                          worst fractal dimension
# mean radius                            -0.018770
# mean texture                            0.173152
# mean perimeter                          0.027128
# mean area                              -0.024583
# mean smoothness                         0.482962
# mean compactness                        0.711206
# mean concavity                          0.532767
# mean concave points                     0.349537
# mean symmetry                           0.429053
# mean fractal dimension                  0.779172
# radius error                            0.009311
# texture error                          -0.032758
# perimeter error                         0.051213
# area error                             -0.015306
# smoothness error                        0.095001
# compactness error                       0.633300
# concavity error                         0.490538
# concave points error                    0.283571
# symmetry error                          0.068782
# fractal dimension error                 0.695351
# worst radius                            0.076485
# worst texture                           0.284785
# worst perimeter                         0.125139
# worst area                              0.060754
# worst smoothness                        0.625461
# worst compactness                       0.831392
# worst concavity                         0.718941
# worst concave points                    0.514009
# worst symmetry                          0.563186
# worst fractal dimension                 1.000000

# %% [markdown]
# ---
# # Övning 2 - Standardisering av X-data
#
# Vi använder `StandardScaler()` för att standardisera vår numeriska X-data (vi standardiserar inte y-datan eftersom den är kategorisk).
#
# Standardisering gör det lättare att tolka samband och jämföra variabler mot varandra. Standardiserad data har följande egenskaper:
# - medelvärde=0
# - standardavvikelse=1
#
# Notera att det finns olika typer av skalning för olika situationer, neurala nätverk använder t.ex. oftast `MinMaxScaler` istället för `StandardScaler`, som normaliserar data så att alla datapunkter hamnar inom spannet 0 och 1.
#
# **Uppgifter**:
#
# 1. Vilken av `X_train, X_test, y_train, y_test` bör vi använda för att träna vår scaler?
#   <details><summary>Hint</summary>Använd aldrig testdata när för att träna en modell</details>
#   <details><summary>Lösning</summary>X_train_scaled = scaler.fit_transform(X_train)</details>
# 2. Vilken av `X_train, X_test, y_train, y_test` bör vi använda när vi ska transformera (men inte träna) vår scaler?
#   <details><summary>Hint</summary>Vi ska använda testdata</details>
#   <details><summary>Lösning</summary>X_test_scaled = scaler.transform(X_test)</details>

# %%
from sklearn.preprocessing import StandardScaler

# Definiera vår scaler
scaler = StandardScaler()

# 2.1. Träna scaler på träningsdata
X_train_scaled = scaler.fit_transform(X_train)

# 2.2 Transformera testdata
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ---
# # Övning 3 - Träning och prediktion
#
# Vi ska använda den skalade träningsdatan för att träna en modell, och sedan den skalade testdatan för att ta fram prediktioner.
#
# Slutligen så ska vi räkna ut en confusion matrix där vi kan se hur många av de predicerade värdena för respektive utfall som faktiskt var korrekta enligt "facit"
#
# **Uppgifter**:
# 1. Definiera en logistik regressionsmodell enligt: `model = <modell som vi har importerat>()`
#   <details><summary>Hint</summary>Titta på vilken modell vi importerar</details>
#   <details><summary>Lösning</summary>model = LogisticRegression()</details>
# 2. Träna modellen med träningsdata enligt: `model.fit(<X-data>, <y-data>)`
#   <details><summary>Hint</summary>Använd aldrig testdata för att träna en modell och kom ihåg att använda skalad X-data</details>
#   <details><summary>Lösning</summary>model.fit(X_train_scaled, y_train)</details>
# 3. Predicera med testdata enligt: `model.predict(<X-data>)`
#   <details><summary>Hint</summary>Använd den skalade testdatan för att predicera</details>
#   <details><summary>Lösning</summary>model.predict(X_test_scaled)</details>
# 4. Ta fram en confusion matrix enligt: `confusion_matrix(<sann y-data>, <predicerad y-data>)`
#   <details><summary>Hint</summary>Använd facit-data och de prediktioner vi fått ut</details>
#   <details><summary>Lösning</summary>cm = confusion_matrix(y_test, y_pred)</details>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# 3.1. Välj modelltyp
model = LogisticRegression()

# 3.2 Träna modell
model.fit(X_train_scaled, y_train)

# 3.3 Gör prediktioner
y_pred = model.predict(X_test_scaled)

# 3.4 Confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm = pd.DataFrame(cm, columns=["predicted_benign", "predicted_maglignant"], index=["actually_benign", "actually_malignant"])
display(cm)
# Out:
#                     predicted_benign  predicted_maglignant
# actually_benign                  144                     0
# actually_malignant                 9                    75

# %% [markdown]
# ---
# # Övning 4 - Utvärdera modellen
#
# Vi kan tolka modellen utifrån ett antal olika mått. I det här fallet så kommer vi inspektera confusion matrix, samt beräkna accuracy.
# - Notera att accuracy kan vara missvisande när datan i y är väldigt obalanserad (t.ex. om nästan alla fall har samma utfall) - vi kommer inte titta på det nu, men bra att känna till
#
# **Uppgifter:**
# 1. Räkna ut `accuracy` (andel korrekta prediktioner)
#   <details><summary>Hint</summary>accuracy = korrekta prediktioner / alla prediktioner</details>
#   <details><summary>Lösning</summary>accuracy = number_of_correct_predictions / number_of_predictions </details>
# 2. Försök tolka `accuracy` och confusion matrix (`cm`)
#   - Hur väl verkar modellen prestera överlag?
#   - Jämför resultatet för de två utfallen "malignant" och "benign" i confusion matrix, verkar modellen vara bra på att predicera båda utfallen?

# %%
# 4.1. Beräkna accuracy
number_of_correct_predictions = sum(y_test == y_pred) 
number_of_predictions = len(y_pred)
accuracy = number_of_correct_predictions / number_of_predictions
print(f"{accuracy=:.2f}")

# 4.2. Tolka accuracy och confusion matrix
display(cm)

"""
<skriv din tolkning här>



""";
# Out:
# accuracy=0.96
#                     predicted_benign  predicted_maglignant
# actually_benign                  144                     0
# actually_malignant                 9                    75

# %% [markdown]
# ---
# # Övning 5 - Skriv in egna X-värden få en prediktion
#
# När vi har en tränad modell som vi är nöjd med så kan vi börja föra in ny data och göra prediktioner.
#
# **Uppgift**:
# 1. Testa skriv in egen X-data och se hur det påverkar det predicerade utfallet
#   - Skriv in kolumnnamn och dess värde (titta i tabellen x_variables nedan för hitta namnen och rimliga värden)
#   - Försök lista ut vilka variabler som ökar/minskar sannolikheten mest
#   <details><summary>Hint</summary>Titta i x_variables för att se vilka variabler som har högre/lägre koefficienter</details>
#
# Notera att vi i det här fallet använder `model.predict_proba()` för att få ut sannolikheterna i procent; `model.predict()` skulle ge oss den faktiska prediktionen (t.ex. "malignant")

# %%
# 5.1. Enter custom data: {"variable name": value}
custom_data = [{
    "mean concave points": 0.05,
    "worst area": 892,
    "radius error": 0.4,
    "mean area": 700,
    "worst symmetry": 0.3,
}]

# Update patient_data
patient_data = pd.DataFrame([X_train.mean()])
patient_data.update(custom_data)
patient_data_scaled = scaler.transform(patient_data)

# Predict outcome
prediction = model.predict_proba(patient_data_scaled)[0][1] * 100
print(f"Predicted probability of malignant tumor: {prediction:.1f}%")

# %%
# Inspect X variables
x_variables = pd.DataFrame(model.coef_, columns=X_train.columns, index=["Coefficient"]).T
x_variables["Mean value"] = X_train.mean()
x_variables["Min value"] = X_train.min()
x_variables["Max value"] = X_train.max()
x_variables["Standard deviation"] = X_train.std()
display(x_variables)

# %% [markdown]
# ---
# # Övning 6 - Fri lek
#
# Har ni tid över så kan ni testa på att jobba med data/modeller helt själva.
#
# **Förslag**:
# - Hitta fler pandas-funktioner här: [Pandas CheatSheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# - Hitta fler sklearn-funktioner här: [sklearn CheatSheet](https://res.cloudinary.com/dyd911kmh/image/upload/v1676302389/Marketing/Blog/Scikit-Learn_Cheat_Sheet.pdf)
# - Räkna ut fler utvärderingsmått - presterar modellen bra enligt alla mått?
#   - `precison = true_positive / (true_positive + false_positive)`
#   - `recall = true_positive / (true_positive + false_negative)`
#   - `f1 = 2 * (precision * recall) / (precision + recall)`
# - Gå t.ex. till [sklearn.datasets](https://scikit-learn.org/stable/datasets/toy_dataset.html) och hitta fler slags modeller att träna
#   - Notera att vilken y-variabel du väljer påverkar vilken slags modell du kan använda; kategoriska y-variabler kräver en modeller av typen "classification", medan numeriska y-variabler kräver modeller av typen "regression" (inte att förväxla med regressionsmodell)
# - Gå t.ex. till [sklearn.linear_model](https://scikit-learn.org/stable/modules/linear_model.html) och hitta flera dataset att analysera

# %%
# Vi kan använda pandas för att skapa nya tabeller och en massa annat
outcomes = pd.DataFrame()                                            # Skapar en tom dataframe
outcomes["count"] = y_train.value_counts()                           # Ny kolumn som består av value_counts() för y
outcomes["proportion"] = round(outcomes["count"] / len(y_train), 2)  # Ny kolumn där vi delar count med antalet rader i y_train
outcomes["percent"] = outcomes["proportion"] * 100                   # Ny kolumn där vi räknar om proportion till procent
outcomes.loc["total"] = outcomes.apply(sum)                          # Ny rad där vi summerar kolumnernas värden
display(outcomes)                                                    # Visar vår nya tabell

# Vi kan skriva ut rader, kolumner och celler för sig
counts = dict(outcomes["count"])      # Kolumnen count
totals = dict(outcomes.loc["total"])  # Raden total
benign = outcomes["count"]["benign"]  # Cellen [count, benign]

print(f"{counts = }")
print(f"{totals = }")
print(f"{benign = }")

# %%
# Vi kan även spara dataframe som .csv, .excel och liknande format
# Notera: I vänsterfliken i google colab finns en tab som heter "Files" där filer sparas/läses från
outcomes.to_csv("outcomes.csv")

# Samt ladda in från .csv, m.fl
outcomes = pd.read_csv("outcomes.csv", index_col=0)
display(outcomes)
